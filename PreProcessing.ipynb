# %%
import pandas as pd 
import numpy as np

TWEET_DATA = pd.read_csv("data_klasifikasi.csv", encoding = "ISO-8859-1")
TWEET_DATA['tweet'].str.encode('ascii', 'ignore')
TWEET_DATA.head()
# Out:
#                                                tweet klasifikasi
# 0  pemerintah lampung bantuan mahasiswa derasnya ...    negative
# 1  pemerintah menerapkan herd immunity kemampuan ...    negative
# 2  lakukan makanan berbuka sahur 10 kepala keluar...    positive
# 3  warga positif corona bupati kondisi menuntut k...    positive
# 4  emosi banget kondisi disuruh liputan covid dos...    negative

# %%
 #------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].str.lower()


print('Case Folding Result : \n')
print(TWEET_DATA['tweet'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    pemerintah lampung bantuan mahasiswa derasnya ...
# 1    pemerintah menerapkan herd immunity kemampuan ...
# 2    lakukan makanan berbuka sahur 10 kepala keluar...
# 3    warga positif corona bupati kondisi menuntut k...
# 4    emosi banget kondisi disuruh liputan covid dos...
# Name: tweet, dtype: object

# %%
import string 
import re #regex library
import nltk
nltk.download('punkt')
# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['tweet'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(TWEET_DATA['tweet_tokens'].head())
print('\n\n\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Tokenizing Result :
#
# 0    [pemerintah, lampung, bantuan, mahasiswa, dera...
# 1    [pemerintah, menerapkan, herd, immunity, kemam...
# 2    [lakukan, makanan, berbuka, sahur, kepala, kel...
# 3    [warga, positif, corona, bupati, kondisi, menu...
# 4    [emosi, banget, kondisi, disuruh, liputan, cov...
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['tweet_tokens_fdist'] = TWEET_DATA['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
print(TWEET_DATA['tweet_tokens_fdist'].head().apply(lambda x : x.most_common()))
# Out:
# Frequency Tokens :
#
# 0    [(pemerintah, 2), (lampung, 2), (bantuan, 1), ...
# 1    [(pemerintah, 2), (menerapkan, 1), (herd, 1), ...
# 2    [(lakukan, 1), (makanan, 1), (berbuka, 1), (sa...
# 3    [(bantaeng, 3), (warga, 1), (positif, 1), (cor...
# 4    [(disuruh, 2), (liputan, 2), (emosi, 1), (bang...
# Name: tweet_tokens_fdist, dtype: object

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')
print(len(list_stopwords))

# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])
len(list_stopwords)
# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwordbahasa.csv", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
len(list_stopwords)
# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 


print(TWEET_DATA['tweet_tokens_WSW'].head())
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 758
# 0    [pemerintah, lampung, bantuan, mahasiswa, dera...
# 1    [pemerintah, menerapkan, herd, immunity, kemam...
# 2    [lakukan, makanan, berbuka, sahur, kepala, kel...
# 3    [warga, positif, corona, bupati, kondisi, menu...
# 4    [emosi, banget, kondisi, disuruh, liputan, cov...
# Name: tweet_tokens_WSW, dtype: object

# %%
normalizad_word = pd.read_csv("normal.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)

TWEET_DATA['tweet_normalized'].head(10)
# Out:
# 0    [pemerintah, lampung, bantuan, mahasiswa, dera...
# 1    [pemerintah, menerapkan, herd, immunity, kemam...
# 2    [lakukan, makanan, berbuka, sahur, kepala, kel...
# 3    [warga, positif, corona, bupati, kondisi, menu...
# 4    [emosi, banget, kondisi, disuruh, liputan, cov...
# 5    [antisipa, penyebaran, pandemi, covid, membutu...
# 6    [bang, pemerintah, peduli, republik, rakyat, c...
# 7    [updates, terkini, covid, kamis, sumber, dinas...
# 8    [pie, menteri, keuangan, sri, mulyani, pemerin...
# 9    [beruntung, ribuan, warga, mati, terdaftar, ko...
# Name: tweet_normalized, dtype: object

# %%
# import Sastrawi package
# !pip install Sastrawi
# !pip install swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_normalized'].swifter.apply(get_stemmed_term)
print(TWEET_DATA['tweet_tokens_stemmed'])
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 15.0 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting swifter
#   Downloading swifter-1.0.9-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.6.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.1.5)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.2)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (3.3.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.41.1)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 15.8 MB/s
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (21.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 32.9 MB/s
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.19.5)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.1)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.0.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.7.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.1)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach>=3.1.1->swifter) (2.4.7)
# Installing collected packages: locket, partd, fsspec, psutil, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed fsspec-2021.7.0 locket-0.2.1 partd-1.2.0 psutil-5.8.0 swifter-1.0.9
# Streaming output truncated to the last 5000 lines.
# maafmeninggal : maafmeninggal
# covidkali : covidkali
# fibrianto : fibrianto
# dufn : dufn
# county : county
# giveawayalert : giveawayalert
# dermaga : dermaga
# hapus : hapus
# pertalite : pertalite
# menyelundupkan : selundup
# menggolkan : gol
# begni : begni
# ajadah : ajadah
# awaskorupsisaveekonomi : awaskorupsisaveekonomi
# netralitas : netralitas
# etik : etik
# bahagianya : bahagia
# herawati : herawati
# menggodog : menggodog
# surip : surip
# kaloran : kalor
# thileng : thileng
# terbuncit : buncit
# kwkwkwk : kwkwkwk
# tapipemerintahnya : tapipemerintahnya
# idafauziyah : idafauziyah
# uni : uni
# worldometers : worldometers
# important : important
# notice : notice
# bangtan : bangtan
# dengerinelshintaaja : dengerinelshintaaja
# menyemprotkan : semprot
# lokckdown : lokckdown
# indosatcare : indosatcare
# terimakasihbppt : terimakasihbppt
# semparuk : semparuk
# indonesiahariini : indonesiahariini
# tetapproduktifamancovid : tetapproduktifamancovid
# plnuntuknegeri : plnuntuknegeri
# ene : ene
# rekonstruksi : rekonstruksi
# tenagakesehatan : tenagakesehatan
# covidbukan : covidbukan
# terseret : seret
# penanagan : penanagan
# hadeeeh : hadeeeh
# patangkep : patangkep
# tutui : tutu
# smtown : smtown
# ygentertainment : ygentertainment
# bighitentertainment : bighitentertainment
# iiiiiiihaw : iiiiiiihaw
# daripda : daripda
# wakwakwakwaksssss : wakwakwakwaksssss
# curvanya : curvanya
# gadisilang : gadisilang
# ngeributin : ngeributin
# nyelenggarain : nyelenggarain
# jawb : jawb
# aep : aep
# mberitakke : mberitakke
# astagah : astagah
# pencitraaan : pencitraaan
# kepakaran : pakar
# semangatku : semangat
# sebangun : bangun
# kabulaten : kabulaten
# sobatpatr : sobatpatr
# gubernurjawatimur : gubernurjawatimur
# gubernurjatim : gubernurjatim
# gubernurkhofifah : gubernurkhofifah
# khofifahindarparawansa : khofifahindarparawansa
# dibolehkannya : boleh
# keroyokan : keroyokan
# evitanursanty : evitanursanty
# nevi : nevi
# zuairina : zuairina
# pkssumbar : pkssumbar
# beritapkssumbar : beritapkssumbar
# irwanprayitno : irwanprayitno
# infosumbarnet : infosumbarnet
# alarm : alarm
# bubawa : bubawa
# halut : halut
# ketertinggalan : tinggal
# doauntuknegara : doauntuknegara
# karwil : karwil
# ld : ld
# jarakin : jarakin
# infounjaya : infounjaya
# slemanis : slemanis
# safekosmlg : safekosmlg
# kosmu : kosmu
# menhan : menhan
# amggaran : amggaran
# terisi : isi
# mngalokasikan : mngalokasikan
# berjangka : jangka
# mip : mip
# kapsipi : kapsipi
# behentinya : behentinya
# petanggungjawaban : petanggungjawaban
# keblakang : keblakang
# when : when
# footprints : footprints
# nggggggg : nggggggg
# materinya : materi
# dipercayamasyarakat : dipercayamasyarakat
# empower : empower
# themselves : themselves
# hutapea : hutapea
# gupa : gupa
# sepat : sepat
# masaran : masaran
# buahan : buah
# timah : timah
# grenase : grenase
# lening : lening
# paret : paret
# pegajahan : gajah
# papuankridamai : papuankridamai
# disiplincegahgelombangke : disiplincegahgelombangke
# agency : agency
# berasnya : beras
# batukaru : batukaru
# expose : expose
# kesedaran : dar
# australiacyberattack : australiacyberattack
# pogba : pogba
# kintap : kintap
# nirwan : nirwan
# anestesi : anestesi
# dradjad : dradjad
# optimotis : optimotis
# taksir : taksir
# sekolahzorah : sekolahzorah
# indonesiasehatekonomikuat : indonesiasehatekonomikuat
# pemerintahtipurakyat : pemerintahtipurakyat
# febrian : febrian
# winanto : winanto
# pudjoharsoyo : pudjoharsoyo
# rempanga : rempanga
# tapikan : tapi
# kro : kro
# rupsnya : rupsnya
# wajarlah : wajar
# dividen : dividen
# lembaganya : lembaga
# mninggal : mninggal
# pdt : pdt
# yones : yones
# eenda : eenda
# sdgn : sdgn
# jurusan : jurus
# saintek : saintek
# kangguru : kangguru
# donaldtrump : donaldtrump
# shaff : shaff
# barokallah : barokallah
# insa : insa
# buibuu : buibuu
# nakerja : nakerja
# fansign : fansign
# album : album
# labyrinth : labyrinth
# daegu : daegu
# busan : bus
# yancheon : yancheon
# pendeknya : pendek
# sulaiman : sulaiman
# gubernursulsel : gubernursulsel
# jatimtangguh : jatimtangguh
# bapendajatim : bapendajatim
# samsatjatimnewnormal : samsatjatimnewnormal
# pembangkitan : bangkit
# bintibsos : bintibsos
# wktnya : wktnya
# screenshot : screenshot
# pasha : pasha
# regimen : regimen
# manjung : manjung
# indarto : indarto
# perfom : perfom
# kakanda : kakanda
# mutmainah : mutmainah
# kabarartis : kabarartis
# gosip : gosip
# terutangnya : utang
# ppsu : ppsu
# gambir : gambir
# mempertanggungjawabkan : mempertanggungjawabkan
# awkwwkk : awkwwkk
# nontonin : nontonin
# ngelaksanain : ngelaksanain
# himbuaan : himbuaan
# perumbulog : perumbulog
# coro : coro
# memulihka : memulihka
# menhendaki : menhendaki
# pelayananannya : pelayananannya
# radiosmartfm : radiosmartfm
# macondo : macondo
# hundred : hundred
# solitude : solitude
# keputusanny : keputusanny
# katun : katun
# jadiberdamai : jadiberdamai
# dengak : dengak
# tribunwow : tribunwow
# ndalu : ndalu
# mrantau : mrantau
# ajeng : ajeng
# tangled : tangled
# menopo : topo
# saged : saged
# nampi : nampi
# mriki : mriki
# angsal : angsal
# dereng : dereng
# netep : netep
# tanggungjawabnya : tanggungjawabnya
# munta : munta
# westandforsultanhamidii : westandforsultanhamidii
# indihomesehubungan : indihomesehubungan
# kebersihanyara : kebersihanyara
# menstimulasi : stimulasi
# kehandalan : kehandalan
# kasuran : kasur
# margomulyo : margomulyo
# difitnah : fitnah
# jouska : jouska
# mengallokasikan : mengallokasikan
# tundukkan : tunduk
# telekom : telekom
# nutrivebenecol : nutrivebenecol
# rtpcr : rtpcr
# bantulsmartcity : bantulsmartcity
# sahutin : sahutin
# clearobat : clearobat
# oplosan : oplos
# keganjenan : ganjen
# kiht : kiht
# kdl : kdl
# mirnamsi : mirnamsi
# mks : mks
# pergerakantakut : pergerakantakut
# uus : uus
# kuswanto : kuswanto
# hutahaean : hutahaean
# jhonny : jhonny
# mandarsyah : mandarsyah
# siaranpers : siaranpers
# haryono : haryono
# hasim : hasim
# alfa : alfa
# haryonopatroli : haryonopatroli
# protovol : protovol
# maxim : maxim
# bike : bike
# risen : risen
# although : although
# menakeridafauziyah : menakeridafauziyah
# bowotimumun : bowotimumun
# pgc : pgc
# cililitan : cililitan
# kapanewon : kapanewon
# tolok : tolok
# universitasandalas : universitasandalas
# arista : arista
# aviation : aviation
# aiac : aiac
# atmadjati : atmadjati
# beritainternasional : beritainternasional
# kepmi : kepmi
# mantol : mantol
# masukkk : masukkk
# bwtbente : bwtbente
# tolnya : tol
# kasuscorona : kasuscorona
# bahayangara : bahayangara
# bojana : bojana
# perjuanganuntukkomunis : perjuanganuntukkomunis
# pengurangpenghasilanbruto : pengurangpenghasilanbruto
# hamzat : hamzat
# jntexpressid : jntexpressid
# tends : tends
# batc : batc
# manila : manila
# bamtc : bamtc
# eksporimpor : eksporimpor
# mmbntu : mmbntu
# shngga : shngga
# pnybran : pnybran
# pasiencoronadiindonesia : pasiencoronadiindonesia
# isak : isak
# muchlis : muchlis
# hamdi : hamdi
# setdknya : setdknya
# disearse : disearse
# newslinebisnismetrotv : newslinebisnismetrotv
# saan : saan
# kepending : pending
# menyaingi : saing
# samasobat : samasobat
# pembahasanya : bahasa
# mskaban : mskaban
# santa : santa
# duren : duren
# rumahibdadah : rumahibdadah
# marketnya : marketnya
# berkomiten : berkomiten
# prospek : prospek
# sulaturahmi : sulaturahmi
# purnawirawan : purnawirawan
# keatasan : atas
# neto : neto
# pajakpenghasilan : pajakpenghasilan
# mejalankan : mejalankan
# faur : faur
# jetika : jetika
# oem : oem
# lasti : lasti
# menurutkuinginnya : menurutkuinginnya
# gunadarma : gunadarma
# tengger : tengger
# prevensi : prevensi
# mnjga : mnjga
# mnjlankan : mnjlankan
# simplicity : simplicity
# kemrin : kemrin
# lbhyogya : lbhyogya
# udahlaaaahh : udahlaaaahh
# gazmahadi : gazmahadi
# kotapinang : kotapinang
# marbun : marbun
# pelaturan : latur
# suyatman : suyatman
# purbasari : purbasari
# raisa : raisa
# cantiknya : cantik
# galon : galon
# dikritk : dikritk
# sampahnya : sampah
# mybastianos : mybastianos
# membasuh : basuh
# kebersiahan : siah
# bastianosdapnyos : bastianosdapnyos
# bastianosrestaurant : bastianosrestaurant
# kawasanmegamasmanado : kawasanmegamasmanado
# manadodiberkat : manadodiberkat
# hewani : hewani
# perunggasan : unggas
# penelaahan : telaah
# strategic : strategic
# lutfi : lutfi
# tersu : tersu
# porduk : porduk
# mmiliki : mmiliki
# blow : blow
# mengindari : mengindari
# imsolusindo : imsolusindo
# imsacademy : imsacademy
# digenjot : genjot
# bersamakitakuat : bersamakitakuat
# umumny : umumny
# khadijah : khadijah
# khimar : khimar
# miconos : miconos
# microscopy : microscopy
# ngevonis : ngevonis
# serahkakn : serahkakn
# menidakan : tidak
# uzur : uzur
# tawaf : tawaf
# penghiburan : hibur
# diberik : berik
# hikmat : hikmat
# fiscal : fiscal
# deficit : deficit
# taytbtalks : taytbtalks
# taytb : taytb
# satgasnusantara : satgasnusantara
# irfo : irfo
# baolan : baolan
# sibea : sibea
# lampasio : lampasio
# dilebihkan : lebih
# impitan : impit
# skep : skep
# mewaspadainya : waspada
# menggatal : gatal
# upayaa : upayaa
# sekaliii : sekaliii
# dasarmandi : dasarmandi
# empang : empang
# marsudi : marsudi
# dialosaya : dialosaya
# miseni : miseni
# dexamethasone : dexamethasone
# handojo : handojo
# barhaji : barhaji
# ekspornya : ekspor
# bolivia : bolivia
# siarkan : siar
# sakaratul : sakaratul
# twuitmu : twuitmu
# kpdmu : kpdmu
# balaknya : balak
# silangkitang : silangkitang
# lamiran : lamiran
# tempurung : tempurung
# goti : got
# perkawinan : kawin
# kabupatenbogor : kabupatenbogor
# berdedikasi : dedikasi
# penyambung : sambung
# katar : katar
# pontir : pontir
# uunya : uunya
# dipidana : pidana
# apman : apman
# ideayogya : ideayogya
# kapas : kapas
# menyumbag : menyumbag
# shinichikudo : shinichikudo
# ngkongroses : ngkongroses
# performance : performance
# kuliahan : kuliah
# anehkadang : anehkadang
# brimobjabar : brimobjabar
# memindah : pindah
# melia : melia
# ut : ut
# upbjj : upbjj
# fadel : fadel
# penilaianku : nilai
# pirkirkan : pirkirkan
# restrukturisasipinjamanlpdbkumkm : restrukturisasipinjamanlpdbkumkm
# lpdbkumkm : lpdbkumkm
# yeeeaaa : yeeeaaa
# then : then
# guber : guber
# volarepagi : volarepagi
# ppspusakajayapasirkuda : ppspusakajayapasirkuda
# tanjungpandan : tanjungpandan
# ketekok : ketekok
# muhamadiyah : muhamadiyah
# nodong : nodong
# menilik : tilik
# akhrinya : akhrinya
# skrinning : skrinning
# katalog : katalog
# purchasing : purchasing
# dimundurin : dimundurin
# perkuliahanmadiun : perkuliahanmadiun
# sebelas : sebelas
# saporkren : saporkren
# produktifamancovid : produktifamancovid
# sekdaprov : sekdaprov
# babah : babah
# ustadchen : ustadchen
# apacerita : apacerita
# ktalk : ktalk
# dibutuhkannya : butuh
# ivan : ivan
# administratif : administratif
# tigabandung : tigabandung
# sudahlahlah : sudahlahlah
# menantiku : nanti
# dianjurin : dianjurin
# rustamaji : rustamaji
# putap : putap
# kinerjapolridiapresiasi : kinerjapolridiapresiasi
# mashup : mashup
# pantur : pantur
# banjarnahor : banjarnahor
# martabe : martabe
# mend : mend
# dipodium : podium
# lantangny : lantangny
# ayodong : ayodong
# patennya : paten
# teruji : uji
# dinihilkan : nihil
# wargajatim : wargajatim
# kspn : kspn
# tjahjono : tjahjono
# concall : concall
# klien : klien
# ngenilai : ngenilai
# sirkuit : sirkuit
# resepnya : resep
# samatidak : samatidak
# sikut : sikut
# trdepan : trdepan
# brawal : brawal
# dahal : dahal
# covidvirus : covidvirus
# antisipasipengangguran : antisipasipengangguran
# fauziyah : fauziyah
# kenapakuliah : kenapakuliah
# mikirpemerintah : mikirpemerintah
# aduch : aduch
# kaban : kaban
# sekalas : kalas
# asipirasi : asipirasi
# thingking : thingking
# diamankan : aman
# ndasku : ndasku
# ngelu : ngelu
# eg : eg
# duo : duo
# monster : monster
# diestimasi : estimasi
# digit : digit
# sembungan : sembung
# mlokolegi : mlokolegi
# sekomplotan : komplot
# mutualku : mutualku
# sandiman : sandiman
# jfs : jfs
# agungkan : agung
# mehan : mehan
# silaturrahim : silaturrahim
# bukitbarisan : bukitbarisan
# pendambb : pendambb
# jajangk : jajangk
# idws : idws
# qurbansehat : qurbansehat
# tebarqurban : tebarqurban
# umatsehat : umatsehat
# pedulidhuafa : pedulidhuafa
# kaytour : kaytour
# kanker : kanker
# marzuki : marzuki
# alie : alie
# tidakhansoal : tidakhansoal
# itudah : itudah
# newnormaldipariwisata : newnormaldipariwisata
# ajo : ajo
# kumandang : kumandang
# bukitsangkal : bukitsangkal
# kalidoni : kalidoni
# mutual : mutual
# filsafat : filsafat
# mantannya : mantan
# yay : yay
# andini : andini
# saras : saras
# yangon : yangon
# lagibang : lagibang
# rosi : ros
# dkksemarang : dkksemarang
# uhc : uhc
# ajakak : ajakak
# mkasih : mkasih
# panicking : panicking
# grafisnyasob : grafisnyasob
# sepinggan : pinggan
# katanetizen : katanetizen
# pikniksaatpandemi : pikniksaatpandemi
# dil : dil
# february : february
# sku : sku
# riweuh : riweuh
# ketakutanpemerintah : ketakutanpemerintah
# namyoung : namyoung
# privatisasi : privatisasi
# nonrujukan : nonrujukan
# seskab : seskab
# acceptable : acceptable
# umbar : umbar
# sajaa : sajaa
# lenyapnya : lenyap
# newnormallindungidiri : newnormallindungidiri
# kenaikam : kenaikam
# lokdan : lokdan
# mnabang : mnabang
# ngebut : ngebut
# pronojiwo : pronojiwo
# limboto : limboto
# wealah : wealah
# diature : diature
# bertanghung : bertanghung
# edikitnya : edikitnya
# iskak : iskak
# protokolkes : protokolkes
# ketidakterbukaan : ketidakterbukaan
# ranti : ranti
# tuhhhh : tuhhhh
# kannnn : kannnn
# nyirnyir : nyirnyir
# mengendus : endus
# sitasi : sitasi
# whew : whew
# yunani : yunani
# kepresiden : presiden
# nagi : nagi
# sukmana : sukmana
# santrisiagabencana : santrisiagabencana
# rudy : rudy
# penyanggah : sanggah
# tanggerang : tanggerang
# skeinaro : skeinaro
# didapatnya : dapat
# powerbeyondgeneration : powerbeyondgeneration
# penumpangnya : tumpang
# rcep : rcep
# lpkr : lpkr
# sumaterabarat : sumaterabarat
# terkaitharus : terkaitharus
# rumahin : rumahin
# oky : oky
# dimasonugroho : dimasonugroho
# energioptimisme : energioptimisme
# listrikunturakyat : listrikunturakyat
# wusss : wusss
# du : du
# isenglah : iseng
# mengikutijaga : mengikutijaga
# rohul : rohul
# jukir : jukir
# pin : pin
# naskah : naskah
# absetyono : absetyono
# koalisiseni : koalisiseni
# kebijakanseni : kebijakanseni
# perayaaan : perayaaan
# jaraklupa : jaraklupa
# ngemplak : ngemplak
# penanjung : tanjung
# melalu : lalu
# garong : garong
# permaian : permai
# marasa : marasa
# ultimatum : ultimatum
# kedapatan : dapat
# kabuaten : kabuaten
# hrfmnews : hrfmnews
# persebaya : baya
# hardrockin : hardrockin
# anniversary : anniversary
# hardrockfmsby : hardrockfmsby
# hardrockfm : hardrockfm
# dibecandai : dibecandai
# denominasi : denominasi
# penurut : turut
# pencinta : cinta
# gl : gl
# penyeleweng : seleweng
# mmpercepat : mmpercepat
# harapa : harapa
# ksulitan : ksulitan
# disebabkn : disebabkn
# indonesiadarurathumor : indonesiadarurathumor
# dur : dur
# begah : begah
# pencaharianya : pencaharianya
# trdanpak : trdanpak
# rerhadap : rerhadap
# cellicanurrach : cellicanurrach
# pelampiasan : lampias
# dibeginikan : begini
# dilarangtapi : dilarangtapi
# nghujat : nghujat
# ngmall : ngmall
# psbbpercuma : psbbpercuma
# neting : neting
# meh : meh
# ceritakan : cerita
# memebesar : besar
# aremania : aremania
# pajakdaerah : pajakdaerah
# njop : njop
# right : right
# cities : cities
# wicak : wicak
# icon : icon
# yuliasmini : yuliasmini
# risnawati : risnawati
# utami : utami
# walikotasalatiga : walikotasalatiga
# daur : daur
# denganmu : dengan
# jamkesda : jamkesda
# ndra : ndra
# kangdien : kangdien
# kangdin : kangdin
# jend : jend
# pengalokasiaan : pengalokasiaan
# antirasisme : antirasisme
# buletinsore : buletinsore
# dpri : dpri
# dikeadaan : ada
# damsel : damsel
# anisjabar : anisjabar
# penangannya : nang
# kelonjakan : lonjak
# selenghkapnya : selenghkapnya
# excell : excell
# teng : teng
# warujayeng : warujayeng
# kppnwamena : kppnwamena
# rorano : rorano
# holtikultura : holtikultura
# anakindonesia : anakindonesia
# komnasperlindungananak : komnasperlindungananak
# metrotimes : metrotimes
# jackylatuhihin : jackylatuhihin
# dlimas : dlimas
# warsito : warsito
# produsenbertanggung : produsenbertanggung
# dihasilkan : hasil
# pencok : pencok
# kementriankominfo : kementriankominfo
# elemennya : elemen
# head : head
# covidthks : covidthks
# saing : saing
# oxford : oxford
# obg : obg
# firma : firma
# kopiganja : kopiganja
# survai : survai
# dalia : dalia
# dilampirkan : lampir
# csv : csv
# pramono : pramono
# anung : anung
# sgenap : sgenap
# lmg : lmg
# infolmg : infolmg
# lamonganpc : lamonganpc
# lamonganpopuler : lamonganpopuler
# kalongan : kalong
# ungaran : ungar
# indonesialawancorona : indonesialawancorona
# baran : baran
# memakmurkan : makmur
# bahagialah : bahagia
# bengak : bengak
# keder : keder
# natalisa : natalisa
# nyirnyirin : nyirnyirin
# logikalucu : logikalucu
# permprov : permprov
# badui : badui
# pfftt : pfftt
# ngrasakke : ngrasakke
# seabad : abad
# arsenal : arsenal
# rakornaswasin : rakornaswasin
# bisniscni : bisniscni
# mendampak : dampak
# kesolidan : solid
# persiiss : persiiss
# anter : anter
# ceko : ceko
# localisesdgs : localisesdgs
# replikasi : replikasi
# lumbungpangan : lumbungpangan
# anggarancovid : anggarancovid
# pukeh : pukeh
# mumada : mumada
# meunan : meunan
# spin : spin
# bersamamnclawancorona : bersamamnclawancorona
# penyambutan : sambut
# bululawang : bululawang
# pdnu : pdnu
# membedakannya : beda
# nela : nela
# berlanggganan : berlanggganan
# alen : alen
# collaps : collaps
# motivator : motivator
# alurnyaa : alurnyaa
# jusufkalla : jusufkalla
# pamong : pamong
# dirgahyu : dirgahyu
# fairidnaparin : fairidnaparin
# multidimensi : multidimensi
# keberadaa : keberadaa
# berkhir : berkhir
# mengungsikan : ungsi
# ungsikan : ungsi
# worldwar : worldwar
# terhindarkan : hindar
# educated : educated
# banyaa : banyaa
# kasiangimana : kasiangimana
# selong : selong
# tahjiz : tahjiz
# hour : hour
# trailer : trailer
# dimensi : dimensi
# tontontanggal : tontontanggal
# keteledoran : teledor
# fleksibiltas : fleksibiltas
# ruined : ruined
# nangisin : nangisin
# ngampus : ngampus
# memungkinan : mungkin
# bombastis : bombastis
# pahamsm : pahamsm
# hanifah : hanifah
# widyarenee : widyarenee
# dilewati : lewat
# alhandulillah : alhandulillah
# prospektif : prospektif
# heuh : heuh
# pangannya : pangan
# boring : boring
# ketidakjujuran : ketidakjujuran
# dikdas : dikdas
# terkonfimasi : terkonfimasi
# klikdokter : klikdokter
# wikusuryomukti : wikusuryomukti
# hajinwajib : hajinwajib
# jabtannya : jabtannya
# rewardnya : rewardnya
# negakin : negakin
# emilu : emilu
# malaka : malaka
# personelnya : personel
# sbdinfo : sbdinfo
# kujawab : jawab
# kerjaanmu : kerja
# jaksakawalprogrampen : jaksakawalprogrampen
# kapasitaskuu : kapasitaskuu
# rakorwil : rakorwil
# sepemikiran : pikir
# memperkerjakan : kerja
# menjerumus : jerumus
# lt : lt
# bernegosiasi : negosiasi
# implement : implement
# tta : tta
# diktator : diktator
# korupsinya : korupsi
# ayokkesumbawa : ayokkesumbawa
# sumbawabarat : sumbawabarat
# sumbawatourism : sumbawatourism
# tatakelolanya : tatakelolanya
# prosesurnya : prosesurnya
# outenya : outenya
# hearing : hearing
# optik : optik
# dorm : dorm
# infection : infection
# ifr : ifr
# rengasdengklok : rengasdengklok
# supandi : supandi
# ujang : ujang
# romli : romli
# dsa : dsa
# kutakarya : kutakarya
# kutawaluya : kutawaluya
# bubble : bubble
# tgan : tgan
# banyakterkait : banyakterkait
# ruby : ruby
# alamsyah : alamsyah
# forensic : forensic
# anshari : anshari
# tulah : tulah
# forkopinca : forkopinca
# puskes : puskes
# binsos : binsos
# bungur : bungur
# haibunda : haibunda
# menjajah : jajah
# pemaaf : maaf
# penyabar : sabar
# ptsp : ptsp
# kabarbireuen : kabarbireuen
# bobmizwar : bobmizwar
# lucah : lucah
# bermulanya : mula
# mengobrak : mengobrak
# abrik : abrik
# teralih : alih
# dikambinghitamkan : dikambinghitamkan
# difisit : difisit
# penggennya : gen
# granddepokcity : granddepokcity
# rumahdepok : rumahdepok
# gdc : gdc
# clustermurah : clustermurah
# rumahminimalis : rumahminimalis
# rumahmurah : rumahmurah
# belirumah : belirumah
# rumahidaman : rumahidaman
# nuryadi : nuryadi
# diremsikan : diremsikan
# mendomi : dom
# jaladri : jaladri
# disiplinnewnormal : disiplinnewnormal
# nct : nct
# ambassador : ambassador
# panion : panion
# sale : sale
# nctdream : nctdream
# hopeful : hopeful
# perlambat : lambat
# forkopincam : forkopincam
# gatra : gatra
# komisipapua : komisipapua
# keroom : keroom
# cipinang : cipinang
# malaya : malaya
# prefemtifcegahcorona : prefemtifcegahcorona
# mykawanbaru : mykawanbaru
# kedat : kedat
# rispect : rispect
# pemuncak : puncak
# tabung : tabung
# oxfor : oxfor
# stimulusnya : stimulus
# rodrigo : rodrigo
# duterte : duterte
# utangpemerintah : utangpemerintah
# kehadiranmu : hadir
# kumpulan : kumpul
# politisisahabat : politisisahabat
# konstituennya : konstituen
# apeksicovid : apeksicovid
# diwakilkan : wakil
# lhuurr : lhuurr
# disamarkan : samar
# covidkoit : covidkoit
# xan : xan
# pangsid : pangsid
# cilangkara : cilangkara
# menkopolhukum : menkopolhukum
# chile : chile
# penyebara : bara
# menonjolkan : tonjol
# sepaham : paham
# ded : ded
# politikgw : politikgw
# timpang : timpang
# omnimbus : omnimbus
# situmorang : situmorang
# prm : prm
# alang : alang
# meruapakan : meruapakan
# hindarkan : hindar
# birin : birin
# gimanapemerintah : gimanapemerintah
# direfokusing : direfokusing
# penanganaan : penanganaan
# disperindagjabar : disperindagjabar
# taucek : taucek
# kediren : kediren
# lembeyan : lembeyan
# mensuplay : mensuplay
# rutanbangli : rutanbangli
# sidangonline : sidangonline
# bantuncairanbakteri : bantuncairanbakteri
# antaradaily : antaradaily
# koch : koch
# sikluspedia : sikluspedia
# cuka : cuka
# berpotensinya : potensi
# mpk : mpk
# tunasi : tunas
# marcusrashford : marcusrashford
# kutu : kutu
# tungau : tungau
# dor : dor
# percayagais : percayagais
# sangkyuuu : sangkyuuu
# bersinar : sinar
# rumbang : rumbang
# rayu : rayu
# cawang : cawang
# kavling : kavling
# sindangsari : sindangsari
# ferdiansyah : ferdiansyah
# ahdi : ahdi
# merapkan : rap
# tabel : tabel
# awan : awan
# dirangkai : rangkai
# semunya : semu
# kampungnya : kampung
# sanakkeu : sanakkeu
# yuhronurefendi : yuhronurefendi
# terlewatkan : lewat
# kepalabirohumasdanprotokol : kepalabirohumasdanprotokol
# sekdaaceh : sekdaaceh
# saban : saban
# awali : awal
# punggul : punggul
# kepolorejo : kepolorejo
# harjuno : harjuno
# goplo : goplo
# juno : juno
# meproduksi : meproduksi
# handmade : handmade
# geluti : gelut
# dompet : dompet
# rekondisi : rekondisi
# umpamakan : umpama
# qrjabar : qrjabar
# kalikong : kalikong
# oknumnya : oknum
# pariera : pariera
# sisakan : sisa
# wanareja : wanareja
# pernag : pernag
# diskonlistrik : diskonlistrik
# kasepuhan : kasepuhan
# ciptagelar : ciptagelar
# sirnaresmi : sirnaresmi
# munitynetworks : munitynetworks
# digitalaccessprogram : digitalaccessprogram
# ruralict : ruralict
# ruralmedialab : ruralmedialab
# ruralinnovation : ruralinnovation
# perburuan : buru
# rente : rente
# asimetri : asimetri
# lincah : lincah
# aviv : aviv
# kaarangkebagusan : kaarangkebagusan
# amanproduktif : amanproduktif
# bandinginnya : bandinginnya
# ndangak : ndangak
# biluri : bilur
# resky : resky
# pip : pip
# frasksi : frasksi
# alhabsyi : alhabsyi
# menegenai : menegenai
# aborsi : aborsi
# sambutnewnormal : sambutnewnormal
# dominos : dominos
# atensinya : atensi
# blacklivematter : blacklivematter
# pemerintahtundabahasruuhip : pemerintahtundabahasruuhip
# pandeglang : pandeglang
# lipsus : lipsus
# prankkerja : prankkerja
# dipalsukan : palsu
# beny : beny
# iyayg : iyayg
# begongarti : begongarti
# kadus : kadus
# pemogan : pemogan
# humassekpejagoan : humassekpejagoan
# polsekpejagoan : polsekpejagoan
# polreskebumen : polreskebumen
# berlakumenyesuaikan : berlakumenyesuaikan
# japri : japri
# rentalmobil : rentalmobil
# rentalmobilbandung : rentalmobilbandung
# rentalmobilpremium : rentalmobilpremium
# sewamobil : sewamobil
# diantyyasmin : diantyyasmin
# masihlah : masih
# menylesaikan : menylesaikan
# lindungidiri : lindungidiri
# lindungioranglain : lindungioranglain
# azzam : azzam
# fatih : fatih
# sepert : sepert
# branch : branch
# executive : executive
# diinterview : diinterview
# mencampur : campur
# signalingkali : signalingkali
# pendopoan : pendopo
# hektare : hektare
# rontok : rontok
# kapastitas : kapastitas
# interaktif : interaktif
# harry : harry
# ngapai : ngapai
# dbilng : dbilng
# bngung : bngung
# yadi : yad
# ariyanto : ariyanto
# bawanya : bawa
# kefamenanu : kefamenanu
# alihprofesinya : alihprofesinya
# inisiasinya : inisiasi
# istimewah : istimewah
# jamali : jamal
# muis : mu
# wkwkwkww : wkwkwkww
# kegabutan : kegabutan
# peneng : neng
# nazreen : nazreen
# nawaz : nawaz
# tsmbah : tsmbah
# tempuran : tempur
# jaipong : jaipong
# biya : biya
# mensahkn : mensahkn
# sasarandisahkan : sasarandisahkan
# peler : peler
# jabarkan : jabar
# mengingitkan : mengingitkan
# rtg : rtg
# clue : clue
# dihutangin : dihutangin
# dijanjiinnya : dijanjiinnya
# banayk : banayk
# temaneg : temaneg
# menkum : menkum
# menghianati : menghianati
# afiat : afiat
# terbukakayak : terbukakayak
# kcw : kcw
# jurnalist : jurnalist
# bidik : bidik
# karangkandri : karangkandri
# peninjauannya : tinjau
# profylh : profylh
# dtanjung : dtanjung
# wagimandeep : wagimandeep
# angedespoir : angedespoir
# yradianto : yradianto
# vita : vita
# avp : avp
# kakeksemelekete : kakeksemelekete
# bodohmu : bodoh
# humasprotokolbantul : humasprotokolbantul
# fanboy : fanboy
# workout : workout
# corana : corana
# lpmk : lpmk
# polehan : polehan
# setyabudi : setyabudi
# ehhhh : ehhhh
# gasengaja : gasengaja
# mint : mint
# contactless : contactless
# terdampal : dampal
# pengisaha : pengisaha
# merela : rela
# yahnsalah : yahnsalah
# ingetunpopular : ingetunpopular
# mengusik : usik
# munculkan : muncul
# ujub : ujub
# rakyatkawaldanacovid : rakyatkawaldanacovid
# sandiwaranoveljilid : sandiwaranoveljilid
# robikinemhas : robikinemhas
# kerumumunan : kerumumunan
# lv : lv
# rusly : rusly
# moti : moti
# salamuddin : salamuddin
# dibatasin : dibatasin
# kesewenangan : wenang
# konsesus : konsesus
# sbesar : sbesar
# dadu : dadu
# pelupa : lupa
# mencurahkan : curah
# aktifitasnya : aktifitasnya
# gejalanya : gejala
# pemerimtah : rim
# jamkerjaasn : jamkerjaasn
# elshintaedisimalam : elshintaedisimalam
# duapekan : duapekan
# sanggarbelajar : sanggarbelajar
# rumaa : rumaa
# qatar : qatar
# provesonal : provesonal
# hbwlgzj : hbwlgzj
# teross : teross
# ujicoba : ujicoba
# wasin : wasin
# dexamethasoneearly : dexamethasoneearly
# results : results
# yt : yt
# wingi : wing
# sadurunge : sadurunge
# percayaaja : percayaaja
# plombokan : plombokan
# fakirmiskin : fakirmiskin
# rillex : rillex
# dilingkaran : lingkar
# mbahas : mbahas
# nglayani : nglayani
# twntang : twntang
# workfromoffice : workfromoffice
# abangan : abangan
# marcus : marcus
# rashford : rashford
# champ : champ
# uyunan : uyunan
# membahasnya : bahas
# pengusul : usul
# berdialog : dialog
# taurots : taurots
# ptpp : ptpp
# nena : nena
# wea : wea
# jadinyagini : jadinyagini
# laos : laos
# bubarkanbumnhantu : bubarkanbumnhantu
# tractors : tractors
# ember : ember
# empud : empud
# hapusruuhipdarimukabumi : hapusruuhipdarimukabumi
# membaikindonesia : membaikindonesia
# dwngannpenanganan : dwngannpenanganan
# empirik : empirik
# kenensosri : kenensosri
# kassim : kassim
# majaliwa : majaliwa
# memgatakan : memgatakan
# pengumumannya : umum
# arinal : arinal
# djunaidi : djunaidi
# nunik : nunik
# rianasariarinal : rianasariarinal
# fahrizal : fahrizal
# rising : rising
# millions : millions
# tkdd : tkdd
# trap : trap
# penangaman : penangaman
# petaninya : petan
# penebaran : tebar
# musnahkan : musnah
# aamiiiin : aamiiiin
# akdesma : akdesma
# province : province
# purwakarata : purwakarata
# urgensijya : urgensijya
# mengamalkan : amal
# normalkan : normal
# ohtemankeu : ohtemankeu
# briliant : briliant
# apbnkita : apbnkita
# trtular : trtular
# susa : susa
# poor : poor
# tundapemerintahtundabahasruuhip : tundapemerintahtundabahasruuhip
# lebib : lebib
# politiktoday : politiktoday
# bocorkan : bocor
# inklusi : inklusi
# eksklusi : eksklusi
# tundaruuhip : tundaruuhip
# biromultimedia : biromultimedia
# lawang : lawang
# mobilelabbslbppt : mobilelabbslbppt
# kucoba : coba
# tpakd : tpakd
# wandoka : wandoka
# wangi : wangi
# gafaruddin : gafaruddin
# diwujudkannya : wujud
# tundah : tundah
# instagramdown : instagramdown
# fran : fran
# dialokasikannya : alokasi
# riauofficial : riauofficial
# cikini : cikini
# mendom : dom
# fraksinasdem : fraksinasdem
# kesehatanancaman : kesehatanancaman
# yakkk : yakkk
# buzz : buzz
# appresasi : appresasi
# disipilin : disipilin
# mbokdari : mbokdari
# keseragaman : seragam
# menyelaraskan : selaras
# cye : cye
# harusny : harusny
# mengutak : kutak
# bijakbersosmed : bijakbersosmed
# dyahroroestiwp : dyahroroestiwp
# edar : edar
# dinkeskotadepok : dinkeskotadepok
# labkesda : labkesda
# karangsambung : karangsambung
# kalibawang : kalibawang
# clarify : clarify
# seek : seek
# immediately : immediately
# obatcovid : obatcovid
# kembalisekolah : kembalisekolah
# mengupload : mengupload
# upppd : upppd
# pensiun : pensiun
# demokratprorakyat : demokratprorakyat
# memin : min
# hamidi : hamidi
# kayulabu : kayulabu
# roro : roro
# esti : esti
# riska : riska
# pratiwi : pratiwi
# menkonya : menkonya
# sinerginaya : sinerginaya
# lakilaki : lakilaki
# tipetipe : tipetipe
# diindikasi : indikasi
# ajarannya : ajar
# mengais : kais
# khilafiyah : khilafiyah
# perkiraannya : kira
# plandemi : plandemi
# ngutak : ngutak
# sinerginya : sinergi
# lawpak : lawpak
# kritiknya : kritik
# sgini : sgini
# question : question
# lumpuhnya : lumpuh
# utarapolda : utarapolda
# poldasuluthumas : poldasuluthumas
# polantasid : polantasid
# polisijatim : polisijatim
# kuaasang : kuaasang
# rokoh : rokoh
# tamini : tamini
# kabapayokumbuah : kabapayokumbuah
# pemerintahngurusin : pemerintahngurusin
# roniyuzirman : roniyuzirman
# adisusilo : adisusilo
# tongoh : tongoh
# disgancing : disgancing
# dario : dario
# silva : silva
# guangdong : guangdong
# keyakinannya : yakin
# dtegakakkan : dtegakakkan
# koalisipdp : koalisipdp
# lindungidatapribadi : lindungidatapribadi
# sahkanruupdp : sahkanruupdp
# elsamnews : elsamnews
# laodemsyarif : laodemsyarif
# dedikasinya : dedikasi
# energitakberhenti : energitakberhenti
# covidsafebumn : covidsafebumn
# sci : sci
# binar : binar
# sahabatlipi : sahabatlipi
# hasden : hasden
# amai : ama
# nurbaiti : nurbaiti
# provoke : provoke
# protelindo : protelindo
# mengulik : ulik
# disiplinnewnormalguys : disiplinnewnormalguys
# sony : sony
# osborn : osborn
# danumkm : danumkm
# pedagangan : dagang
# disalurinnya : disalurinnya
# userstory : userstory
# apandemi : apandemi
# diselidiki : selidik
# poltek : poltek
# goodbye : goodbye
# sobatrbpn : sobatrbpn
# dala : dala
# humaskarawang : humaskarawang
# dinaskominfokrw : dinaskominfokrw
# kabkarawang : kabkarawang
# pedan : dan
# disipinnewnormal : disipinnewnormal
# penggal : penggal
# kua : kua
# laboratoriumavianflu : laboratoriumavianflu
# fluburung : fluburung
# redarmy : redarmy
# mainmenyelewengkan : mainmenyelewengkan
# ernestprakasa : ernestprakasa
# menyangsikan : sangsi
# jamane : jamane
# totop : totop
# tahlilan : tahlil
# prei : prei
# meteng : meteng
# indonesiamausehat : indonesiamausehat
# barigas : barigas
# mantaaab : mantaaab
# selewengkan : seleweng
# dikeras : keras
# nian : nian
# gunonyo : gunonyo
# penyebearan : penyebearan
# infopenanews : infopenanews
# displinnewnormal : displinnewnormal
# luculu : luculu
# lsr : lsr
# lpmt : lpmt
# hapuskan : hapus
# jadiharus : jadiharus
# gimanatiba : gimanatiba
# dokumentasi : dokumentasi
# berasrama : asrama
# bimbel : bimbel
# diskominfobdgkab : diskominfobdgkab
# unsr : unsr
# yosi : yos
# mediana : mediana
# pgsd : pgsd
# pedagogik : pedagogik
# indonesiamembutuhkanmu : indonesiamembutuhkanmu
# upikampuscibiru : upikampuscibiru
# blablablablublublu : blablablablublublu
# sutomo : sutomo
# penjuang : juang
# kaidipang : kaidipang
# depri : depri
# spesifik : spesifik
# terdongkrak : dongkrak
# kspk : kspk
# diswab : diswab
# samling : samling
# chefallah : chefallah
# memories : memories
# chef : chef
# koherensi : koherensi
# amanlupa : amanlupa
# shareteman : shareteman
# kkniain : kkniain
# panai : panai
# bamin : bamin
# rijal : rijal
# berombang : berombang
# cityofsydney : cityofsydney
# tercurah : curah
# sehrusnya : sehrusnya
# kemndikbud : kemndikbud
# romantiasi : romantiasi
# rncana : rncana
# nyatany : nyatany
# dgang : dgang
# diedukasi : edukasi
# enjinir : enjinir
# gaklah : gaklah
# polije : polije
# bejiharjo : bejiharjo
# kuswandi : kuswandi
# idbilling : idbilling
# formatnya : format
# enok : enok
# leye : leye
# kebintang : bintang
# matinta : matinta
# terhimpit : terhimpit
# ampen : ampen
# syamrizal : syamrizal
# qosasi : qosasi
# pasarcovid : pasarcovid
# troops : troops
# slanjtnya : slanjtnya
# komika : komika
# menyiasatinya : siasat
# kkniainbatusangkar : kkniainbatusangkar
# perbincangannya : bincang
# suaramerdeka : suaramerdeka
# bengkuku : bengku
# heyy : heyy
# pindhin : pindhin
# tiketpesawat : tiketpesawat
# listiarty : listiarty
# kemarau : kemarau
# djauhari : djauhari
# oratmangun : oratmangun
# senaputrafm : senaputrafm
# dikementrian : tri
# papuadamaisejahtera : papuadamaisejahtera
# memperparahnya : parah
# kokkesusu : kokkesusu
# championship : championship
# hebei : hebei
# calling : calling
# captains : captains
# ceksuhutubuh : ceksuhutubuh
# lebel : lebel
# intensifnya : intensif
# profesinya : profesi
# vivitra : vivitra
# pinere : pere
# rsuza : rsuza
# bukog : bukog
# oasti : oasti
# priti : prit
# patel : patel
# padalengsar : padalengsar
# bunikasih : bunikasih
# warungkondang : warungkondang
# humaspolrscjr : humaspolrscjr
# gombong : gombong
# songgom : songgom
# gekbrong : gekbrong
# kebugaran : bugar
# alergi : alergi
# plish : plish
# minded : minded
# konteksya : konteksya
# dikonteks : konteks
# cepa : cepa
# nggun : nggun
# knpiaceh : knpiaceh
# menkopolhukammahfudmd : menkopolhukammahfudmd
# pemerintahpastikankebijakanpenanganancoviddilaksanakandenganbaik : pemerintahpastikankebijakanpenanganancoviddilaksanakandenganbaik
# flexing : flexing
# irl : irl
# pertamabagus : pertamabagus
# keduamungkin : keduamungkin
# placebo : placebo
# kepaksaan : paksa
# anjiriya : anjiriya
# anggara : anggara
# patungan : patungan
# suzon : suzon
# menyalahakan : menyalahakan
# ginanjar : ganjar
# bingkeng : bingkeng
# dayeuhluhur : dayeuhluhur
# bkmt : bkmt
# higienis : higienis
# sodik : sodik
# psda : psda
# pusdajatim : pusdajatim
# welang : wang
# pekalen : pekalen
# bengawan : bengawan
# blasss : blasss
# salahku : salah
# pungkiri : pungkiri
# cmp : cmp
# crisisnya : crisisnya
# backfires : backfires
# bertanggal : tanggal
# izinkeramaian : izinkeramaian
# onsite : onsite
# omnibuslawcariperhatian : omnibuslawcariperhatian
# kumulo : kumulo
# jeruk : jeruk
# sumanto : sumanto
# geneng : geneng
# karenaemang : karenaemang
# ketegasanjokowi : ketegasanjokowi
# resta : resta
# curas : curas
# curanmor : curanmor
# melandaipemerintah : melandaipemerintah
# carena : carena
# swa : swa
# terutamanya : utama
# padepokan : padepokan
# mengdiskriditkan : mengdiskriditkan
# formilnya : formilnya
# menteribaikerickthohir : menteribaikerickthohir
# piawai : piawai
# hmtifnyawiji : hmtifnyawiji
# penyertanya : serta
# waktunyalokadata : waktunyalokadata
# pemudi : pemudi
# wargamu : warga
# pengamatsosial : pengamatsosial
# mehimbau : mehimbau
# mengantakan : anta
# pertunjukan : tunjuk
# cen : cen
# anjingnya : anjing
# haselo : haselo
# semuwaberita : semuwaberita
# iyy : iyy
# anjayy : anjayy
# dhl : dhl
# pisangan : pisang
# yka : yka
# elpiji : elpiji
# ggal : ggal
# windusari : windusari
# balesari : balesari
# peuteuycondong : peuteuycondong
# memdukung : memdukung
# fspmi : fspmi
# kemdagri : kemdagri
# rejodani : rejodani
# ngadiyono : ngadiyono
# gubernurbahlul : gubernurbahlul
# bersinggungan : singgung
# bakery : bakery
# bakers : bakers
# keresidenan : residen
# berterusan : terus
# perubahannya : ubah
# towers : towers
# tmht : tmht
# rsuzabandaaceh : rsuzabandaaceh
# ruangisolasi : ruangisolasi
# kognitif : kognitif
# kelun : kelun
# lenteng : lenteng
# karsa : karsa
# portalsurya : portalsurya
# ngrawat : ngrawat
# pandemikcuma : pandemikcuma
# seterserahpun : serah
# bkalketubruk : bkalketubruk
# jebakan : jebak
# leicester : leicester
# gencer : gencer
# berkebunkeren : berkebunkeren
# pertanianindonesia : pertanianindonesia
# sibut : sibut
# dikertas : kertas
# triliuan : triliuan
# olvy : olvy
# andrianita : andrianita
# lada : lada
# jabang : jabang
# harikeluargaberencana : harikeluargaberencana
# menaklukkan : takluk
# tolakadudombafokuspandemi : tolakadudombafokuspandemi
# porlescilacap : porlescilacap
# konda : konda
# uho : uho
# kecurigaan : curiga
# memasok : pasok
# ahma : ahma
# wifi : wifi
# cornernya : cornernya
# corner : corner
# tutupkak : tutupkak
# galle : galle
# kolombo : kolombo
# lanka : lanka
# stokpangan : stokpangan
# blabak : blabak
# huseinsn : huseinsn
# hariannya : hari
# mengamplifikasi : amplifikasi
# pengritik : pengritik
# kenyatannya : kenyat
# maknya : maknya
# perlambatin : perlambatin
# tunggangannya : tunggang
# rakyatbengkulu : rakyatbengkulu
# dukungruuhip : dukungruuhip
# pancasilaabadi : pancasilaabadi
# pancasilasakti : pancasilasakti
# diremehin : diremehin
# dibujuk : bujuk
# kelapangan : lapang
# simeulue : simeulue
# erli : erli
# cucitanganmu : cucitanganmu
# dasteran : daster
# berdaster : daster
# sekerak : kerak
# tamiang : tamiang
# jayawijaya : jayawijaya
# soleman : soleman
# garaan : garaan
# psbblah : psbblah
# menggangu : menggangu
# clusterpencegahancovidaceh : clusterpencegahancovidaceh
# letsgo : letsgo
# nyukur : nyukur
# lupattp : lupattp
# sapanang : sapanang
# rauf : rauf
# landea : landea
# bungoro : bungoro
# cibuaya : cibuaya
# sulistio : sulistio
# astambul : astambul
# patuhui : patuhui
# perorang : orang
# penjaminan : jamin
# ngreco : ngreco
# manekin : manekin
# kebjiakan : kebjiakan
# fitnahnya : fitnah
# pemerintahtolakadudombafokuspandemi : pemerintahtolakadudombafokuspandemi
# brtngung : brtngung
# wondering : wondering
# jaganama : jaganama
# diperbantukan : bantu
# mufakat : mufakat
# lstana : lstana
# pendirita : pendirita
# persekolahan : sekolah
# anjirla : anjirla
# susipudjiastuti : susipudjiastuti
# stabilan : stabil
# mengkonstruksi : konstruksi
# pengaburan : abur
# bumnmajuindonesiamaju : bumnmajuindonesiamaju
# citakerja : citakerja
# pleass : pleass
# reshufflekabinetjokowi : reshufflekabinetjokowi
# kainewnormal : kainewnormal
# jagakarsa : jagakarsa
# dom : dom
# diiklankan : iklan
# menthol : menthol
# ppds : ppds
# sederhanaajang : sederhanaajang
# kardaya : kardaya
# sudag : sudag
# aggrn : aggrn
# klojen : klojen
# mendengarnya : dengar
# lpj : lpj
# rehsuffle : rehsuffle
# bungsu : bungsu
# arwana : arwana
# setres : tres
# lgh : lgh
# chanel : chanel
# deminkri : deminkri
# cofirmation : cofirmation
# tantowi : tantowi
# keunggulan : unggul
# efesiensi : efesiensi
# hmkm : hmkm
# ketandan : tandan
# polrikawaladaptasibaru : polrikawaladaptasibaru
# nonaktifkan : nonaktif
# iriawan : iriawan
# sepakbolaid : sepakbolaid
# videobola : videobola
# sepakbolajakarta : sepakbolajakarta
# sepakboladunia : sepakboladunia
# fansbola : fansbola
# palingan : paling
# berolok : olok
# mempropagandakan : propaganda
# memuakkan : muak
# tambrauw : tambrauw
# sedik : dik
# fluktuasinya : fluktuasi
# sideways : sideways
# kema : kema
# pojokan : pojok
# lambene : lambene
# mengucur : kucur
# hcm : hcm
# pemerintahi : perintah
# kerasukan : rasuk
# arwah : arwah
# menepati : tepat
# gejalakita : gejalakita
# cintaan : cinta
# nirfaedah : nirfaedah
# sepertix : sepertix
# mendptkn : mendptkn
# rinjani : rinjani
# bm : bm
# whitelistnya : whitelistnya
# gumushh : gumushh
# ngebentengin : ngebentengin
# aktivisnya : aktivis
# ngehantam : ngehantam
# bineka : bineka
# herianto : herianto
# nyala : nyala
# mahaiswa : mahaiswa
# cileuleuy : cileuleuy
# presidendableg : presidendableg
# kabung : kabung
# rohingya : rohingya
# tenggulun : tenggulun
# pememeritah : per
# konservatif : konservatif
# kuponnya : kupon
# rumania : rumania
# cekik : cekik
# pnspunya : pnspunya
# gadai : gadai
# ringkusprovokatorsaatpandemi : ringkusprovokatorsaatpandemi
# menjg : menjg
# setc : setc
# sepasang : pasang
# maryam : maryam
# fotografer : fotografer
# tour : tour
# sukowisesa : sukowisesa
# pakem : pakem
# melcosh : melcosh
# bagaimanakalau : bagaimanakalau
# jekan : jekan
# kecurangan : curang
# ekportir : ekportir
# fidz : fidz
# dimaanfaatin : dimaanfaatin
# cashless : cashless
# nfc : nfc
# yukz : yukz
# diorder : order
# jlantah : jlantah
# wawan : wawan
# gobang : gobang
# finus : finus
# sukamanah : sukamanah
# gsosialisasikan : gsosialisasikan
# kanoman : kanoman
# rilpan : rilpan
# mengsosialisasikan : mengsosialisasikan
# joni : joni
# willem : willem
# bandi : bandi
# banyu : banyu
# habang : habang
# rawen : rawen
# berbenturan : bentur
# rapide : rapide
# hidjau : hidjau
# porpi : porpi
# berbadan : badan
# propam : propam
# hasbullah : hasbullah
# thabrany : thabrany
# koncet : koncet
# atausi : atausi
# kyt : kyt
# kayamba : kayamba
# gumbs : gumbs
# etnis : etnis
# ditampung : tampung
# stopprovokasifokuscovid : stopprovokasifokuscovid
# menyelamat : selamat
# newnormaldemirakyat : newnormaldemirakyat
# penetrasi : penetrasi
# tempat : tempat
# benerkaan : benerkaan
# pembuktiannya : bukti
# banto : banto
# virralkan : virralkan
# percy : percy
# chinsla : chinsla
# falevi : falevi
# sejutamaskerpoldajatim : sejutamaskerpoldajatim
# subsidilistrikgratis : subsidilistrikgratis
# causes : causes
# terusdr : terusdr
# bahasannya : bahas
# polresmojokertokota : polresmojokertokota
# disampaikansama : disampaikansama
# subsidilistrikpln : subsidilistrikpln
# yawes : yawes
# garek : garek
# kadivhumas : kadivhumas
# diklarifikasi : klarifikasi
# kawandalamperubahan : kawandalamperubahan
# printahkan : printahkan
# menengahnya : tengah
# onar : onar
# difungsikannya : fungsi
# namanyapun : nama
# dukunganya : dukunganya
# jagajokowi : jagajokowi
# erickout : erickout
# waspadahoaks : waspadahoaks
# ditebar : tebar
# sukarami : sukarami
# mis : mis
# ibpindonesia : ibpindonesia
# kotamojokerto : kotamojokerto
# menjembatani : jembatan
# berantam : rantam
# irih : irih
# mmpus : mmpus
# melakskan : melakskan
# gosong : gosong
# kufur : kufur
# beloved : beloved
# customers : customers
# berpikire : berpikire
# mbokmenowo : mbokmenowo
# dirangkum : rangkum
# locals : locals
# ketemennya : ketemennya
# kangblk : kangblk
# akuntabilitasdanacovid : akuntabilitasdanacovid
# danacovid : danacovid
# milikmu : milik
# lemkaspa : lemkaspa
# nyinyirannya : nyinyir
# poris : poris
# plawad : plawad
# kirani : kiran
# dprk : dprk
# sterilkan : steril
# meuraxa : meuraxa
# gakwarga : gakwarga
# orangkaya : orangkaya
# tersesat : sesat
# myembassyjkt : myembassyjkt
# tetapibelum : tetapibelum
# lapindo : lapindo
# meningakatkan : meningakatkan
# ekomomi : ekomomi
# ditegah : tegah
# nkripedulipapua : nkripedulipapua
# row : row
# pms : pms
# njlimet : njlimet
# dengarkanlah : dengar
# nfn : nfn
# ...
# mungkur : mungkur
# suzenko : suzenko
# chairy : chairy
# ajaahh : ajaahh
# dokk : dokk
# haduuh : haduuh
# ruangguru : ruangguru
# penggalan : penggal
# namamu : nama
# sanubariku : sanubari
# sofi : sofi
# her : her
# cece : cece
# safitri : safitri
# alrazzak : alrazzak
# disinigaes : disinigaes
# penggunaanthermo : penggunaanthermo
# dengancara : dengancara
# perkim : kim
# satgasnya : satgasnya
# kompetensinya : kompetensi
# dikoordinasi : koordinasi
# perekonomiankayak : perekonomiankayak
# terintimidasi : intimidasi
# pentol : pentol
# korek : korek
# diborong : borong
# ampundah : ampundah
# gardan : gardan
# antimalaria : antimalaria
# mghantam : mghantam
# mahalngr : mahalngr
# ahela : ahela
# konprasi : konprasi
# cinahangout : cinahangout
# dimanaaa : dimanaaa
# jovid : jovid
# tjandra : tjandra
# dibalikmya : dibalikmya
# klinikrpk : klinikrpk
# rpkfm : rpkfm
# emba : emba
# dilogikakali : dilogikakali
# staysantuy : staysantuy
# islamiceducation : islamiceducation
# kkndriainkendari : kkndriainkendari
# iainkendari : iainkendari
# tuduhanmu : tuduh
# eknmi : eknmi
# tengah : tengah
# ngra : ngra
# perwira : perwira
# sesko : sesko
# menengaskan : tengas
# pernyataaan : pernyataaan
# akipagi : akipagi
# propose : propose
# mengimunisasi : imunisasi
# oercaya : oercaya
# mebgatasi : mebgatasi
# pnddkan : pnddkan
# berpusat : pusat
# kebebsan : kebebsan
# berkreasi : kreasi
# sebelgw : sebelgw
# mencyduk : mencyduk
# tertolol : tolol
# nyuntik : nyuntik
# sahabatreligi : sahabatreligi
# segunung : gunung
# mashfaranif : mashfaranif
# setolol : tolol
# diagnosisnya : diagnosis
# rapidtes : rapidtes
# mnctrijayasemarang : mnctrijayasemarang
# thmewarnainegeri : thmewarnainegeri
# papuatidakakanpisah : papuatidakakanpisah
# stadium : stadium
# gobolok : gobolok
# brinews : brinews
# menurutkuinfoe : menurutkuinfoe
# keslahane : keslahane
# erickson : erickson
# pessiwarisa : pessiwarisa
# varicella : varicella
# kemungkianan : kemungkianan
# laporgub : laporgub
# dkksurakarta : dkksurakarta
# terasid : asid
# pemerintahdicoba : pemerintahdicoba
# coviddirapid : coviddirapid
# dirapid : dirapid
# pribadibayar : pribadibayar
# nyairin : nyairin
# mad : mad
# kkndruinsukelompok : kkndruinsukelompok
# kknhoror : kknhoror
# ceritakkn : ceritakkn
# kreatifinovatifdansolidaritas : kreatifinovatifdansolidaritas
# cadangkan : cadang
# kepotong : potong
# darimananyatolong : darimananyatolong
# kegemaran : gemar
# natgeo : natgeo
# prediksiku : prediksi
# gentayangan : gentayang
# percayapun : percaya
# disiplinprotokolkesehatan : disiplinprotokolkesehatan
# gaklo : gaklo
# nguji : nguji
# mutualisme : mutualisme
# ekspresiku : ekspresi
# patahkan : patah
# sabarallah : sabarallah
# dabar : dabar
# sabarrrr : sabarrrr
# dibentuknya : bentuk
# upacaya : upacaya
# karoeke : karoeke
# terbesarnyadari : terbesarnyadari
# gundul : gundul
# berbik : bik
# diselesaiin : diselesaiin
# bagaimanacara : bagaimanacara
# sentralistik : sentralistik
# bhp : bhp
# ciwi : ciwi
# tubir : tubir
# hoaxnya : hoaxnya
# cvd : cvd
# mukenye : mukenye
# mukashaming : mukashaming
# bgtz : bgtz
# nlz : nlz
# sgkt : sgkt
# brdsr : brdsr
# bomerang : bomerang
# bambangbrodjonegoro : bambangbrodjonegoro
# musiman : musim
# gublokkkkkkk : gublokkkkkkk
# melebihkan : lebih
# obrolanya : obrolanya
# syedih : syedih
# mbx : mbx
# ringkas : ringkas
# janjilah : janji
# spesifiknya : spesifik
# bokapnya : bokapnya
# pembayar : bayar
# ngefoto : ngefoto
# kloning : kloning
# kacrutnya : kacrutnya
# menghandel : menghandel
# reckless : reckless
# indecisive : indecisive
# utterly : utterly
# naomychs : naomychs
# soetomo : soetomo
# filosofisnya : filosofis
# skalanya : skala
# keuang : uang
# siiih : siiih
# stonk : stonk
# maeng : maeng
# rituit : rituit
# gowo : gowo
# manalah : mana
# begituyowes : begituyowes
# yagimanakan : yagimanakan
# terimaunit : terimaunit
# lilirilau : lilirilau
# polressoppeng : polressoppeng
# poldasulsel : poldasulsel
# kapolressoppeng : kapolressoppeng
# sekitarn : sekitarn
# nyangkanya : nyangkanya
# nyatanyaga : nyatanyaga
# diagnosanya : diagnosanya
# dilengkapin : dilengkapin
# covidterjun : covidterjun
# bjuang : bjuang
# tersungkur : sungkur
# sbatas : sbatas
# inter : inter
# datapenanganan : datapenanganan
# digiku : digiku
# buntut : buntut
# gaaa : gaaa
# didaftarin : didaftarin
# paster : paster
# uganda : uganda
# klk : klk
# kekyak : kekyak
# informasisobatanggaran : informasisobatanggaran
# hudieracing : hudieracing
# krntau : krntau
# nangkal : nangkal
# komunikasinya : komunikasi
# rsudza : rsudza
# zainoel : zainoel
# rentanlah : rentan
# aglomerasi : aglomerasi
# penyakitini : penyakitini
# multiorgan : multiorgan
# dicibir : cibir
# prestasikah : prestasi
# geloraindonesia : geloraindonesia
# pressrelease : pressrelease
# belanjanya : belanja
# ditambal : tambal
# waktunyokadata : waktunyokadata
# sedianya : sedia
# basmibenalunkridancovid : basmibenalunkridancovid
# nunukan : nunukan
# koremmrl : koremmrl
# instensif : instensif
# acehbesar : acehbesar
# ngaruhnyadibilang : ngaruhnyadibilang
# typus : typus
# maybeee : maybeee
# rayaanggaran : rayaanggaran
# hebohkan : heboh
# adaptsasikebiasaanbaru : adaptsasikebiasaanbaru
# mers : mers
# antibiotik : antibiotik
# disuntikin : disuntikin
# eike : eike
# nakesitupun : nakesitupun
# itungannyaperbulan : itungannyaperbulan
# ramashok : ramashok
# tosari : tosari
# brangsong : brangsong
# kuliahku : kuliah
# trollkesini : trollkesini
# mintanya : minta
# jokowitugaskanerick : jokowitugaskanerick
# carita : carita
# patungannn : patungannn
# penangaaanaaan : penangaaanaaan
# euthanasia : euthanasia
# trafic : trafic
# ac : ac
# triliunkali : triliunkali
# penyesatan : sesat
# perekonimian : perekonimian
# dramatisir : dramatisir
# jasaraharjauntukindonesia : jasaraharjauntukindonesia
# racana : racana
# raumfo : raumfo
# menegaska : menegaska
# lippopenguasari : lippopenguasari
# akartam : akartam
# peeemuuuulihan : peeemuuuulihan
# playen : playen
# pnemumonia : pnemumonia
# naaasionaaaal : naaasionaaaal
# kangelan : kangelan
# yws : yws
# sangar : sangar
# jungpara : jungpara
# pelanggannya : langgan
# tiganya : tiga
# balasannya : balas
# pembimbing : bimbing
# gfsi : gfsi
# tercukupi : cukup
# meikyansyah : meikyansyah
# garnita : garnita
# malahayati : malahayati
# beleid : beleid
# nnn : nnn
# ngusulin : ngusulin
# ekoonomi : ekoonomi
# naaasional : naaasional
# daaan : daaan
# sektoooor : sektoooor
# kartonyono : kartonyono
# kerabatnya : kerabat
# ngareb : ngareb
# mengenyam : kenyam
# mainannya : main
# dera : dera
# tenjolaya : tenjolaya
# gadiurus : gadiurus
# goride : goride
# bidaaang : bidaaang
# nasionaaal : nasionaaal
# kompensasinya : kompensasi
# kebayar : bayar
# oops : oops
# mendoktrin : doktrin
# ginipapaku : ginipapaku
# diapotik : apotik
# dedysusantopj : dedysusantopj
# bisulan : bisul
# helenamantra : helenamantra
# jantho : jantho
# memastiksn : memastiksn
# nuff : nuff
# aromaterapi : aromaterapi
# mewarnai : warna
# kibulan : kibul
# gendovara : gendovara
# menuduhnya : tuduh
# sudirejo : sudirejo
# limun : limun
# himbaua : himbaua
# ditetap : tetap
# kabarhem : kabarhem
# ingat : ingat
# diajarinnya : diajarinnya
# menyampaikannya : sampai
# ikappi : ikappi
# tertulan : tertulan
# kualitatif : kualitatif
# wihana : wihana
# globalgegara : globalgegara
# kemauannya : mau
# brtgg : brtgg
# ttntya : ttntya
# ych : ych
# triangkit : triangkit
# mengeleminasi : mengeleminasi
# jokowibentukkomite : jokowibentukkomite
# dipatahkan : patah
# penebar : tebar
# intesif : intesif
# suvei : suvei
# olimpiade : olimpiade
# paralimpiade : paralimpiade
# pemerintahdari : pemerintahdari
# menongolnya : nongol
# jefrinichol : jefrinichol
# semngatin : semngatin
# elektromedik : elektromedik
# voluntarily : voluntarily
# disesase : disesase
# kirane : kirane
# ngetokno : ngetokno
# duwik : duwik
# jembrot : jembrot
# negoromu : negoromu
# mono : mono
# temankukecerobohan : temankukecerobohan
# bersatulah : satu
# wisman : wisman
# manji : manji
# amatttt : amatttt
# kelesuan : lesu
# memasulkan : memasulkan
# siaplawancovid : siaplawancovid
# rsauantariksa : rsauantariksa
# gercepnya : gercepnya
# dsik : dsik
# sianak : sianak
# bubarkandinastiboneka : bubarkandinastiboneka
# sainsnya : sains
# nirempati : nirempati
# gagapbencana : gagapbencana
# allahsemoga : allahsemoga
# mengaburkan : abur
# akala : akala
# fisioterapis : fisioterapis
# ktpnya : ktpnya
# gelud : gelud
# bunyikan : bunyi
# mengadang : adang
# lihatin : lihatin
# videokan : video
# benalu : benalu
# memanfaat : manfaat
# gakkalau : gakkalau
# healties : healties
# mastercard : mastercard
# wahanavisi : wahanavisi
# hasto : hasto
# kristiyanto : kristiyanto
# kelanjutanya : kelanjutanya
# penerimainsentif : penerimainsentif
# jumlahklu : jumlahklu
# sektorpenerimainsentif : sektorpenerimainsentif
# sektorindustri : sektorindustri
# menhajar : menhajar
# murat : murat
# kapita : kapita
# selekta : selekta
# bersekutu : sekutu
# kaliin : kaliin
# sembiringmemberikan : sembiringmemberikan
# kapolek : kapolek
# pesonil : pesonil
# ayocucitangan : ayocucitangan
# kewibawaan : wibawa
# indonesiainklusi : indonesiainklusi
# infokompmk : infokompmk
# ituloh : ituloh
# dibantahin : dibantahin
# yutak : yutak
# perpasien : pasien
# doktergak : doktergak
# jooo : jooo
# mulutmu : mulut
# tapuk : tapuk
# menghayati : hayati
# kratak : kratak
# capturan : capturan
# yagasih : yagasih
# kenskenni : kenskenni
# dianaidsw : dianaidsw
# pemkotsemarang : pemkotsemarang
# pemeri : meri
# pemulasaraan : pemulasaraan
# supirnya : supirnya
# ngelamar : ngelamar
# setting : setting
# anmemilih : anmemilih
# manadolupa : manadolupa
# siginjai : siginjai
# preemtif : preemtif
# kalitinggal : kalitinggal
# kantongin : kantongin
# kalunging : kalunging
# apresiai : apresiai
# melaka : melaka
# johor : johor
# bahru : bahru
# tkait : tkait
# hg : hg
# bejing : bejing
# mediadigitalcpp : mediadigitalcpp
# annya : annya
# korelasiin : korelasiin
# bergerakbersama : bergerakbersama
# gedawang : gedawang
# kantoran : kantor
# gegoro : gegoro
# diurut : urut
# pijet : pijet
# iroh : iroh
# mijeti : mijeti
# berbusa : busa
# biasangga : biasangga
# kpntingan : kpntingan
# ningkat : ningkat
# caraikutin : caraikutin
# expertise : expertise
# catering : catering
# hajatan : hajat
# infastruktur : infastruktur
# dikoar : koar
# koarin : koarin
# dkasi : dkasi
# kelasonline : kelasonline
# infoseminar : infoseminar
# infopelatihan : infopelatihan
# blah : blah
# rumitaku : rumitaku
# kudokumentasi : dokumentasi
# kushare : kushare
# menambahkan : tambah
# khairul : khairul
# ceritanyabapaknya : ceritanyabapaknya
# sivik : sivik
# cih : cih
# menghambo : menghambo
# hambo : hambo
# bekumpul : bekumpul
# tel : tel
# quds : quds
# netanyahu : netanyahu
# grouppalestine : grouppalestine
# hayuklah : hayuklah
# jelaslengkap : jelaslengkap
# odopisb : odopisb
# komunitasisb : komunitasisb
# ambu : ambu
# lauk : lauk
# bdh : bdh
# ngawas : ngawas
# unfollow : unfollow
# tabi : tabi
# tapin : tapin
# diribetin : diribetin
# menkonfirmasi : menkonfirmasi
# desianwar : desianwar
# aguss : aguss
# kekeyibukanboneka : kekeyibukanboneka
# jessicajane : jessicajane
# listychan : listychan
# erickolim : erickolim
# harieskrimsedunia : harieskrimsedunia
# ngerasaini : ngerasaini
# jon : jon
# nyalip : nyalip
# selamatin : selamatin
# sabdabixu : sabdabixu
# iparku : ipar
# menggosip : gosip
# perorangnyaa : perorangnyaa
# yakalii : yakalii
# tanggepannyaa : tanggepannyaa
# kemensoshadiruntukindonesia : kemensoshadiruntukindonesia
# kekeyi : kekeyi
# dengab : dengab
# diumbar : umbar
# orglain : orglain
# kitajagapapuayuk : kitajagapapuayuk
# ditelen : ditelen
# hebattt : hebattt
# aebagai : aebagai
# kebujakan : kebujakan
# muncullah : muncul
# jengjeng : jengjeng
# malolo : malolo
# yagaksi : yagaksi
# djki : djki
# kumhambantuumkm : kumhambantuumkm
# bgtswab : bgtswab
# ratusam : ratusam
# ppd : ppd
# tertingginya : tinggi
# perumppd : perumppd
# nyeimbangin : nyeimbangin
# lntong : lntong
# mnguatkn : mnguatkn
# napas : napas
# jerinksz : jerinksz
# keluyurann : keluyurann
# {'pemerintah': 'perintah', 'lampung': 'lampung', 'bantuan': 'bantu', 'mahasiswa': 'mahasiswa', 'derasnya': 'deras', 'donasi': 'donasi', 'masuk': 'masuk', 'provinsi': 'provinsi', 'tim': 'tim', 'gugus': 'gugus', 'tugas': 'tugas', 'covid': 'covid', 'menerapkan': 'terap', 'herd': 'herd', 'immunity': 'immunity', 'kemampuan': 'mampu', 'nihil': 'nihil', 'pemberantasan': 'berantas', 'gambling': 'gambling', 'kuat': 'kuat', 'bertahan': 'tahan', 'hidup': 'hidup', 'lemah': 'lemah', 'mati': 'mati', 'negara': 'negara', 'serius': 'serius', 'menangani': 'tangan', 'virus': 'virus', 'lakukan': 'laku', 'makanan': 'makan', 'berbuka': 'buka', 'sahur': 'sahur', 'kepala': 'kepala', 'keluarga': 'keluarga', 'terdampak': 'dampak', 'tasik': 'tasik', 'data': 'data', 'ramadan': 'ramadan', 'rencanakan': 'rencana', 'paket': 'paket', 'sembako': 'sembako', 'lengkap': 'lengkap', 'semoga': 'moga', 'rejekinya': 'rejekinya', 'warga': 'warga', 'positif': 'positif', 'corona': 'corona', 'bupati': 'bupati', 'kondisi': 'kondisi', 'menuntut': 'tuntut', 'kebersamaan': 'sama', 'rakyat': 'rakyat', 'news': 'news', 'bantaeng': 'bantaeng', 'kabupaten': 'kabupaten', 'penanganan': 'tangan', 'merilis': 'rilis', 'rakyatdotnews': 'rakyatdotnews', 'referensiterkini': 'referensiterkini', 'rakyatnews': 'rakyatnews', 'emosi': 'emosi', 'banget': 'banget', 'disuruh': 'suruh', 'liputan': 'liput', 'dosen': 'dosen', 'bercanda': 'canda', 'menyuruh': 'suruh', 'dirumahaja': 'dirumahaja', 'rumah': 'rumah', 'antisipa': 'antisipa', 'penyebaran': 'sebar', 'pandemi': 'pandemi', 'membutuhkan': 'butuh', 'kerja': 'kerja', 'masyarakat': 'masyarakat', 'musibah': 'musibah', 'berkatagori': 'berkatagori', 'non': 'non', 'alam': 'alam', 'prosesnewsid': 'prosesnewsid', 'psbb': 'psbb', 'gorontalo': 'gorontalo', 'bang': 'bang', 'peduli': 'peduli', 'republik': 'republik', 'cina': 'cina', 'urus': 'urus', 'abk': 'abk', 'meninggal': 'tinggal', 'korban': 'korban', 'ratusan': 'ratus', 'indonesia': 'indonesia', 'kasihan': 'kasihan', 'sedih': 'sedih', 'kali': 'kali', 'updates': 'updates', 'terkini': 'kini', 'kamis': 'kamis', 'sumber': 'sumber', 'dinas': 'dinas', 'kesehatan': 'sehat', 'magetan': 'magetan', 'info': 'info', 'grafis': 'grafis', 'angka': 'angka', 'keselamatan': 'selamat', 'waspada': 'waspada', 'panik': 'panik', 'ikuti': 'ikut', 'himbauan': 'himbauan', 'kpulawancovid': 'kpulawancovid', 'pie': 'pie', 'menteri': 'menteri', 'keuangan': 'uang', 'sri': 'sri', 'mulyani': 'mulyani', 'daerah': 'daerah', 'khusus': 'khusus', 'kota': 'kota', 'jakarta': 'jakarta', 'pusat': 'pusat', 'menanggung': 'tanggung', 'bansos': 'bansos', 'alasannya': 'alas', 'keterbatasan': 'batas', 'dana': 'dana', 'skandalamiespemprovdki': 'skandalamiespemprovdki', 'beruntung': 'untung', 'ribuan': 'ribu', 'terdaftar': 'daftar', 'untung': 'untung', 'rugi': 'rugi', 'menolak': 'tolak', 'lock': 'lock', 'down': 'down', 'dipilih': 'pilih', 'jokowi': 'jokowi', 'pilih': 'pilih', 'lockdown': 'lockdown', 'berbahaya': 'bahaya', 'mengatasinya': 'atas', 'sepantas': 'pantas', 'ciduk': 'ciduk', 'bebas': 'bebas', 'jrx': 'jrx', 'berpendapat': 'dapat', 'konspirasi': 'konspirasi', 'disebar': 'sebar', 'luaskan': 'luas', 'pemikiran': 'pikir', 'akal': 'akal', 'akalan': 'akal', 'penyakitnya': 'sakit', 'nyata': 'nyata', 'toxic': 'toxic', 'bego': 'bego', 'denny': 'denny', 'galau': 'galau', 'mudik': 'mudik', 'orang': 'orang', 'tuanya': 'tua', 'dilarang': 'larang', 'menghentikan': 'henti', 'alpa': 'alpa', 'disugesti': 'sugesti', 'tukang': 'tukang', 'sembuhkan': 'sembuh', 'kesurupan': 'surup', 'yuk': 'yuk', 'keseruannya': 'seru', 'sahursegerr': 'sahursegerr', 'gooddoctorid': 'gooddoctorid', 'baikbersama': 'baikbersama', 'salah': 'salah', 'menit': 'menit', 'gara': 'gara', 'santai': 'santai', 'nenek': 'nenek', 'tolak': 'tolak', 'miskin': 'miskin', 'alasan': 'alas', 'jepang': 'jepang', 'setuju': 'tuju', 'remdesivir': 'remdesivir', 'obati': 'obat', 'pasien': 'pasien', 'darisuara': 'darisuara', 'patut': 'patut', 'dicontoh': 'contoh', 'berupaya': 'upaya', 'menyukseskan': 'sukse ...
# ------------------------
# HBox(children=(FloatProgress(value=0.0, description='Pandas Apply', max=36922.0, style=ProgressStyle(descripti…
# 0        [perintah, lampung, bantu, mahasiswa, deras, d...
# 1        [perintah, terap, herd, immunity, mampu, perin...
# 2        [laku, makan, buka, sahur, kepala, keluarga, d...
# 3        [warga, positif, corona, bupati, kondisi, tunt...
# 4        [emosi, banget, kondisi, suruh, liput, covid, ...
#                                ...
# 36917    [hoaks, hoaks, edar, covid, perintah, kendali,...
# 36918    [tinggi, covid, majelis, musyawarat, rakyat, n...
# 36919    [pakai, masker, cuci, hand, sanitizer, nama, i...
# 36920    [kabupaten, aceh, selatan, zona, hijau, libat,...
# 36921    [keluyurann, rumah, kerja, beli, sembako, jala...
# Name: tweet_tokens_stemmed, Length: 36922, dtype: object

# %%
TWEET_DATA.to_csv("Text_Preprocessing.csv")

# %%
TWEET_DATA.to_excel("Text_Preprocessing.xlsx")
